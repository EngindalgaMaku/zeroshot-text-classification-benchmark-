# %% [markdown]
# # Final 2 Experiments - Qwen3 with max_seq_length=512
#
# Bu notebook son 2 deneyi çalıştırır (63/63 tamamlamak için).
#
# **Kalan deneyler:**
# 1. exp_yahoo_answers_topics_qwen3 (1000 sample, 10 class, max_seq_length=512)
# 2. exp_SetFit_20_newsgroups_qwen3 (2000 sample, 20 class, max_seq_length=512)
#
# **Çözüm:** `max_seq_length=512` ile uzun text'ler kesiliyor
#
# **Colab Runtime:** GPU (T4 yeterli)

# %% [markdown]
# ## 1. Kurulum

# %%
# GitHub repository clone
# !git clone https://github.com/EngindalgaMaku/zeroshot-text-classification-benchmark-.git
# %cd zeroshot-text-classification-benchmark-

# %%
# Gerekli kütüphaneleri yükle
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install -q -r requirements.txt

# %% [markdown]
# ## 2. GPU Kontrolü

# %%
import torch
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")

# %% [markdown]
# ## 3. Deney 1: Yahoo Answers Topics (1000 sample, daha hızlı)

# %%
# Yahoo Answers Topics - 1000 sample, 10 class
# !python main.py --config experiments/exp_yahoo_answers_topics_qwen3.yaml

# %% [markdown]
# ## 4. Deney 2: SetFit 20 Newsgroups (2000 sample, daha yavaş)

# %%
# SetFit 20 Newsgroups - 2000 sample, 20 class
# !python main.py --config experiments/exp_SetFit_20_newsgroups_qwen3.yaml

# %% [markdown]
# ## 5. Sonuçları İndir

# %%
# Sonuçları zip olarak indir
# !zip -r final_2_experiments_results.zip results/raw/exp_yahoo_answers_topics_qwen3* results/raw/exp_SetFit_20_newsgroups_qwen3*

from google.colab import files
files.download('final_2_experiments_results.zip')
